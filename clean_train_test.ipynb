# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Internal ipython tool for setting figure size
from IPython.core.pylabtools import figsize
pd.options.display.max_columns = None

# %%
data = pd.read_csv("Ames_data.csv")

# %%
price = data['Sale_Price']
data = data.drop(columns=['Sale_Price'])

# %%
data.shape
# Out:
# (2930, 82)

# %%
# test train split 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data,price,test_size=0.30, random_state=42)

# %%
X_train.shape
# Out:
# (1963, 82)

# %%
X_train.head(3)
# Out:
#             PID                          MS_SubClass                MS_Zoning  \
# 2259  916384050  One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 1615  527105140             Two_Story_1946_and_Newer  Residential_Low_Density
# 1241  535178060  One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
#
#       Lot_Frontage  Lot_Area Street            Alley           Lot_Shape  \
# 2259            67      8368   Pave  No_Alley_Access  Slightly_Irregular
# 1615             0     12394   Pave  No_Alley_Access  Slightly_Irregular
# 1241            72      9000   Pave  No_Alley_Access             Regular
#
#      Land_Contour Utilities Lot_Config Land_Slope Neighborhood Condition_1  \
# 2259          HLS    AllPub     Inside        Gtl   Timberland        Norm
# 1615          Lvl    AllPub     Corner        Gtl      Gilbert        Norm
# 1241          Lvl    AllPub     Inside        Gtl   North_Ames        Norm
#
#      Condition_2 Bldg_Type House_Style   Overall_Qual Overall_Cond  \
# 2259        Norm    OneFam   One_Story           Good      Average
# 1615        Norm    OneFam   Two_Story           Good      Average
# 1241        Norm    OneFam   One_Story  Above_Average      Average
#
#       Year_Built  Year_Remod_Add Roof_Style Roof_Matl Exterior_1st  \
# 2259        2006            2007      Gable   CompShg      VinylSd
# 1615        2003            2003      Gable   CompShg      VinylSd
# 1241        1956            1956      Gable   CompShg      Wd Sdng
#
#      Exterior_2nd Mas_Vnr_Type  Mas_Vnr_Area Exter_Qual Exter_Cond Foundation  \
# 2259      VinylSd         None             0       Good    Typical      PConc
# 1615      VinylSd         None             0       Good    Typical      PConc
# 1241      Wd Sdng      BrkFace            74    Typical    Typical     CBlock
#
#      Bsmt_Qual Bsmt_Cond Bsmt_Exposure BsmtFin_Type_1  BsmtFin_SF_1  \
# 2259      Good   Typical            No            Unf             7
# 1615      Good   Typical            Gd            Unf             7
# 1241      Good   Typical            No            LwQ             4
#
#      BsmtFin_Type_2  BsmtFin_SF_2  Bsmt_Unf_SF  Total_Bsmt_SF Heating  \
# 2259            Unf             0         1689           1689    GasA
# 1615            Unf             0          847            847    GasA
# 1241            Unf             0          580           1196    GasA
#
#      Heating_QC Central_Air Electrical  First_Flr_SF  Second_Flr_SF  \
# 2259  Excellent           Y      SBrkr          1689              0
# 1615  Excellent           Y      SBrkr           847            886
# 1241       Good           Y      FuseA          1196              0
#
#       Low_Qual_Fin_SF  Gr_Liv_Area  Bsmt_Full_Bath  Bsmt_Half_Bath  Full_Bath  \
# 2259                0         1689               0               0          2
# 1615                0         1733               0               0          2
# 1241                0         1196               1               0          1
#
#       Half_Bath  Bedroom_AbvGr  Kitchen_AbvGr Kitchen_Qual  TotRms_AbvGrd  \
# 2259          0              3              1         Good              7
# 1615          1              3              1         Good              7
# 1241          0              2              1      Typical              6
#
#      Functional  Fireplaces  Fireplace_Qu Garage_Type  Garage_Yr_Blt  \
# 2259        Typ           0  No_Fireplace      Attchd         2007.0
# 1615        Typ           1          Good     BuiltIn         2003.0
# 1241        Typ           1          Good      Attchd         1956.0
#
#      Garage_Finish  Garage_Cars  Garage_Area Garage_Qual Garage_Cond  \
# 2259           Fin            2          433     Typical     Typical
# 1615           Fin            2          433     Typical     Typical
# 1241           RFn            1          297     Typical     Typical
#
#      Paved_Drive  Wood_Deck_SF  Open_Porch_SF  Enclosed_Porch  \
# 2259       Paved           100             39               0
# 1615       Paved           100             48               0
# 1241       Paved             0             44               0
#
#       Three_season_porch  Screen_Porch  Pool_Area  Pool_QC     Fence  \
# 2259                   0             0          0  No_Pool  No_Fence
# 1615                   0             0          0  No_Pool  No_Fence
# 1241                   0             0          0  No_Pool  No_Fence
#
#      Misc_Feature  Misc_Val  Mo_Sold  Year_Sold Sale_Type Sale_Condition  \
# 2259         None         0        4       2007       New        Partial
# 1615         None         0       10       2007       WD          Family
# 1241         None         0        5       2008       WD          Normal
#
#       Longitude   Latitude
# 2259 -93.650588  41.994241
# 1615 -93.639880  42.061275
# 1241 -93.614856  42.042187

# %%
X_test.head(4)
# Out:
#             PID                          MS_SubClass  \
# 1357  903427090             Two_Story_1945_and_Older
# 2367  527450460         Two_Story_PUD_1946_and_Newer
# 2822  908128100             Two_Story_1946_and_Newer
# 2126  907135180  One_Story_1946_and_Newer_All_Styles
#
#                        MS_Zoning  Lot_Frontage  Lot_Area Street  \
# 1357  Residential_Medium_Density             0      5100   Pave
# 2367  Residential_Medium_Density            21      1890   Pave
# 2822     Residential_Low_Density            62      7162   Pave
# 2126     Residential_Low_Density            60      8070   Pave
#
#                 Alley Lot_Shape Land_Contour Utilities Lot_Config Land_Slope  \
# 1357           Gravel   Regular          Lvl    AllPub     Inside        Gtl
# 2367  No_Alley_Access   Regular          Lvl    AllPub     Inside        Gtl
# 2822  No_Alley_Access   Regular          Lvl    AllPub     Inside        Gtl
# 2126  No_Alley_Access   Regular          Lvl    AllPub     Inside        Gtl
#
#        Neighborhood Condition_1 Condition_2 Bldg_Type House_Style  \
# 1357       Old_Town        Norm        Norm    OneFam   Two_Story
# 2367      Briardale        Norm        Norm     Twnhs   Two_Story
# 2822        Edwards        Norm        Norm    OneFam   Two_Story
# 2126  College_Creek        Norm        Norm    OneFam   One_Story
#
#        Overall_Qual Overall_Cond  Year_Built  Year_Remod_Add Roof_Style  \
# 1357      Very_Good         Good        1925            1996        Hip
# 2367  Above_Average         Good        1972            1972      Gable
# 2822           Good      Average        2003            2004        Hip
# 2126  Below_Average      Average        1994            1995      Gable
#
#      Roof_Matl Exterior_1st Exterior_2nd Mas_Vnr_Type  Mas_Vnr_Area  \
# 1357   CompShg       Stucco      Wd Shng         None             0
# 2367   CompShg      HdBoard      HdBoard      BrkFace           380
# 2822   CompShg      HdBoard       Stucco      BrkFace           190
# 2126   CompShg      VinylSd      VinylSd         None             0
#
#      Exter_Qual Exter_Cond Foundation Bsmt_Qual Bsmt_Cond Bsmt_Exposure  \
# 1357    Typical       Good      PConc   Typical   Typical            No
# 2367    Typical    Typical     CBlock   Typical   Typical            No
# 2822       Good    Typical      PConc      Good   Typical            No
# 2126    Typical    Typical      PConc      Good   Typical            No
#
#      BsmtFin_Type_1  BsmtFin_SF_1 BsmtFin_Type_2  BsmtFin_SF_2  Bsmt_Unf_SF  \
# 1357            Unf             7            Unf             0          588
# 2367            ALQ             1            Unf             0          212
# 2822            Unf             7            Unf             0          796
# 2126            GLQ             3            Unf             0          402
#
#       Total_Bsmt_SF Heating Heating_QC Central_Air Electrical  First_Flr_SF  \
# 1357            588    GasA       Fair           Y      SBrkr           833
# 2367            494    GasA  Excellent           Y      SBrkr           494
# 2822            796    GasA  Excellent           Y      SBrkr           806
# 2126            990    GasA  Excellent           Y      SBrkr           990
#
#       Second_Flr_SF  Low_Qual_Fin_SF  Gr_Liv_Area  Bsmt_Full_Bath  \
# 1357            833                0         1666               0
# 2367            536                0         1030               0
# 2822            918                0         1724               0
# 2126              0                0          990               1
#
#       Bsmt_Half_Bath  Full_Bath  Half_Bath  Bedroom_AbvGr  Kitchen_AbvGr  \
# 1357               0          1          0              3              1
# 2367               0          1          1              3              1
# 2822               0          2          1              3              1
# 2126               0          1          0              3              1
#
#      Kitchen_Qual  TotRms_AbvGrd Functional  Fireplaces  Fireplace_Qu  \
# 1357         Good              7        Typ           1          Good
# 2367      Typical              6        Typ           0  No_Fireplace
# 2822         Good              8        Typ           1          Good
# 2126      Typical              5        Typ           0  No_Fireplace
#
#      Garage_Type  Garage_Yr_Blt Garage_Finish  Garage_Cars  Garage_Area  \
# 1357      Detchd         1925.0           Unf            1          228
# 2367      Detchd         1973.0           Unf            1          264
# 2822     BuiltIn         2003.0           Fin            2          616
# 2126   No_Garage            NaN     No_Garage            0            0
#
#      Garage_Qual Garage_Cond Paved_Drive  Wood_Deck_SF  Open_Porch_SF  \
# 1357     Typical     Typical       Paved           192             63
# 2367     Typical     Typical       Paved             0              0
# 2822     Typical     Typical       Paved           168             57
# 2126   No_Garage   No_Garage       Paved             0              0
#
#       Enclosed_Porch  Three_season_porch  Screen_Porch  Pool_Area  Pool_QC  \
# 1357               0                   0             0          0  No_Pool
# 2367               0                   0             0          0  No_Pool
# 2822               0                   0             0          0  No_Pool
# 2126               0                   0             0          0  No_Pool
#
#                 Fence Misc_Feature  Misc_Val  Mo_Sold  Year_Sold Sale_Type  \
# 1357  Minimum_Privacy         None         0        6       2008       WD
# 2367         No_Fence         None         0        7       2006       WD
# 2822         No_Fence         None         0        5       2006       WD
# 2126         No_Fence         None         0        8       2007       WD
#
#      Sale_Condition  Longitude   Latitude
# 1357         Normal -93.621065  42.029038
# 2367         Normal -93.627103  42.051798
# 2822         Normal -93.672379  42.018990
# 2126         Normal -93.692415  42.019028

# %%
train = pd.concat([X_train,y_train],axis = 1)
test = pd.concat([X_test,y_test],axis = 1)

# %%
print(train.shape)
print(test.shape)
# Out:
# (1963, 83)
# (967, 83)

# %%
train.to_csv('train.csv')
test.to_csv('test.csv')
